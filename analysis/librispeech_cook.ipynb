# %%
import os
import pandas as pd
import IPython.display as ipd
from pydub.utils import mediainfo
import re
import time

# %% [markdown]
# # Make LibriSpeech Great Again

# %%
paths = [
    "/home/morph/Desktop/FINAL/LS/train-other-500/LibriSpeech",
    "/home/morph/Desktop/FINAL/LS/train-clean-360/LibriSpeech"
]

def load_librispeech_data(paths):
    data = []
    for path in paths:
        for subdir, dirs, files in os.walk(path):
            for file in files:
                if file.endswith('.txt'):
                    file_path = os.path.join(subdir, file)
                    with open(file_path, 'r') as f:
                        for line in f:
                            audio_id, sentence = line.strip().split(maxsplit=1)
                            audio_path = os.path.join(subdir, audio_id + ".flac")
                            data.append([audio_path, sentence])
    return pd.DataFrame(data, columns=["audio_path", "sentence"])

df = load_librispeech_data(paths)
df.head()
# Out:
#                                           audio_path  \
# 0  /home/morph/Desktop/FINAL/LS/train-other-500/L...
# 1  /home/morph/Desktop/FINAL/LS/train-other-500/L...
# 2  /home/morph/Desktop/FINAL/LS/train-other-500/L...
# 3  /home/morph/Desktop/FINAL/LS/train-other-500/L...
# 4  /home/morph/Desktop/FINAL/LS/train-other-500/L...
#
#                                             sentence
# 0  CHAPTER TWENTY FIVE A VISIT FROM LOUISE THAT D...
# 1  TO STIFLE HER WITH HOUSEHOLD AMMONIA AND LIDDY...
# 2  SHE CLUTCHED AT MY SLEEVE WHEN I WENT CLOSE TO...
# 3  COMING JUST AFTER THE FIRE THE HOUSEHOLD WAS D...
# 4  BUT SHE WAS SO EXCITED I WAS AFRAID SHE WOULD ...

# %%
df = df.head(20000)

# %%
len(df)
# Out:
# 20000

# %%
df['sentence'][2]
# Out:
# 'SHE CLUTCHED AT MY SLEEVE WHEN I WENT CLOSE TO HER AND REFUSED TO LET GO'

# %%
ipd.Audio(df['audio_path'][2])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/flac;base64,..." type="audio/flac" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def get_phonemes(text):
    phonemes_list = []
    text = text.lower()
    for sent in sentences(text, 
                          lang="en-US", 
                          espeak=False, 
                          punctuations=False, 
                          major_breaks=False, 
                          minor_breaks=False):
        for word in sent:
            if word.phonemes: 
                phonemes_list.append(''.join(word.phonemes))  

    return ' '.join(phonemes_list)

start_time = time.time()
total_rows = len(df)
print("Начало обработки...")

df['gruut_phonemes'] = ""

for i in range(total_rows):
    sentence = df.loc[i, 'sentence']
    df.at[i, 'gruut_phonemes'] = get_phonemes(sentence) 

    if (i + 1) % 20 == 0 or (i + 1) == total_rows:
        print(f"Обработано {i + 1} строк из {total_rows}")

print("Обработка завершена.")
# Out:
# Начало обработки...
# Обработано 20 строк из 20000
# Обработано 40 строк из 20000
# Обработано 60 строк из 20000
# Обработано 80 строк из 20000
# Обработано 100 строк из 20000
# Обработано 120 строк из 20000
# Обработано 140 строк из 20000
# Обработано 160 строк из 20000
# Обработано 180 строк из 20000
# Обработано 200 строк из 20000
# Обработано 220 строк из 20000
# Обработано 240 строк из 20000
# Обработано 260 строк из 20000
# Обработано 280 строк из 20000
# Обработано 300 строк из 20000
# Обработано 320 строк из 20000
# Обработано 340 строк из 20000
# Обработано 360 строк из 20000
# Обработано 380 строк из 20000
# Обработано 400 строк из 20000
# Обработано 420 строк из 20000
# Обработано 440 строк из 20000
# Обработано 460 строк из 20000
# Обработано 480 строк из 20000
# Обработано 500 строк из 20000
# Обработано 520 строк из 20000
# Обработано 540 строк из 20000
# Обработано 560 строк из 20000
# Обработано 580 строк из 20000
# Обработано 600 строк из 20000
# Обработано 620 строк из 20000
# Обработано 640 строк из 20000
# Обработано 660 строк из 20000
# Обработано 680 строк из 20000
# Обработано 700 строк из 20000
# Обработано 720 строк из 20000
# Обработано 740 строк из 20000
# Обработано 760 строк из 20000
# Обработано 780 строк из 20000
# Обработано 800 строк из 20000
# Обработано 820 строк из 20000
# Обработано 840 строк из 20000
# Обработано 860 строк из 20000
# Обработано 880 строк из 20000
# Обработано 900 строк из 20000
# Обработано 920 строк из 20000
# Обработано 940 строк из 20000
# Обработано 960 строк из 20000
# Обработано 980 строк из 20000
# Обработано 1000 строк из 20000
# Обработано 1020 строк из 20000
# Обработано 1040 строк из 20000
# Обработано 1060 строк из 20000
# Обработано 1080 строк из 20000
# Обработано 1100 строк из 20000
# Обработано 1120 строк из 20000
# Обработано 1140 строк из 20000
# Обработано 1160 строк из 20000
# Обработано 1180 строк из 20000
# Обработано 1200 строк из 20000
# Обработано 1220 строк из 20000
# Обработано 1240 строк из 20000
# Обработано 1260 строк из 20000
# Обработано 1280 строк из 20000
# Обработано 1300 строк из 20000
# Обработано 1320 строк из 20000
# Обработано 1340 строк из 20000
# Обработано 1360 строк из 20000
# Обработано 1380 строк из 20000
# Обработано 1400 строк из 20000
# Обработано 1420 строк из 20000
# Обработано 1440 строк из 20000
# Обработано 1460 строк из 20000
# Обработано 1480 строк из 20000
# Обработано 1500 строк из 20000
# Обработано 1520 строк из 20000
# Обработано 1540 строк из 20000
# Обработано 1560 строк из 20000
# Обработано 1580 строк из 20000
# Обработано 1600 строк из 20000
# Обработано 1620 строк из 20000
# Обработано 1640 строк из 20000
# Обработано 1660 строк из 20000
# Обработано 1680 строк из 20000
# Обработано 1700 строк из 20000
# Обработано 1720 строк из 20000
# Обработано 1740 строк из 20000
# Обработано 1760 строк из 20000
# Обработано 1780 строк из 20000
# Обработано 1800 строк из 20000
# Обработано 1820 строк из 20000
# Обработано 1840 строк из 20000
# Обработано 1860 строк из 20000
# Обработано 1880 строк из 20000
# Обработано 1900 строк из 20000
# Обработано 1920 строк из 20000
# Обработано 1940 строк из 20000
# Обработано 1960 строк из 20000
# Обработано 1980 строк из 20000
# Обработано 2000 строк из 20000
# Обработано 2020 строк из 20000
# Обработано 2040 строк из 20000
# Обработано 2060 строк из 20000
# Обработано 2080 строк из 20000
# Обработано 2100 строк из 20000
# Обработано 2120 строк из 20000
# Обработано 2140 строк из 20000
# Обработано 2160 строк из 20000
# Обработано 2180 строк из 20000
# Обработано 2200 строк из 20000
# Обработано 2220 строк из 20000
# Обработано 2240 строк из 20000
# Обработано 2260 строк из 20000
# Обработано 2280 строк из 20000
# Обработано 2300 строк из 20000
# Обработано 2320 строк из 20000
# Обработано 2340 строк из 20000
# Обработано 2360 строк из 20000
# Обработано 2380 строк из 20000
# Обработано 2400 строк из 20000
# Обработано 2420 строк из 20000
# Обработано 2440 строк из 20000
# Обработано 2460 строк из 20000
# Обработано 2480 строк из 20000
# Обработано 2500 строк из 20000
# Обработано 2520 строк из 20000
# Обработано 2540 строк из 20000
# Обработано 2560 строк из 20000
# Обработано 2580 строк из 20000
# Обработано 2600 строк из 20000
# Обработано 2620 строк из 20000
# Обработано 2640 строк из 20000
# Обработано 2660 строк из 20000
# Обработано 2680 строк из 20000
# Обработано 2700 строк из 20000
# Обработано 2720 строк из 20000
# Обработано 2740 строк из 20000
# Обработано 2760 строк из 20000
# Обработано 2780 строк из 20000
# Обработано 2800 строк из 20000
# Обработано 2820 строк из 20000
# Обработано 2840 строк из 20000
# Обработано 2860 строк из 20000
# Обработано 2880 строк из 20000
# Обработано 2900 строк из 20000
# Обработано 2920 строк из 20000
# Обработано 2940 строк из 20000
# Обработано 2960 строк из 20000
# Обработано 2980 строк из 20000
# Обработано 3000 строк из 20000
# Обработано 3020 строк из 20000
# Обработано 3040 строк из 20000
# Обработано 3060 строк из 20000
# Обработано 3080 строк из 20000
# Обработано 3100 строк из 20000
# Обработано 3120 строк из 20000
# Обработано 3140 строк из 20000
# Обработано 3160 строк из 20000
# Обработано 3180 строк из 20000
# Обработано 3200 строк из 20000
# Обработано 3220 строк из 20000
# Обработано 3240 строк из 20000
# Обработано 3260 строк из 20000
# Обработано 3280 строк из 20000
# Обработано 3300 строк из 20000
# Обработано 3320 строк из 20000
# Обработано 3340 строк из 20000
# Обработано 3360 строк из 20000
# Обработано 3380 строк из 20000
# Обработано 3400 строк из 20000
# Обработано 3420 строк из 20000
# Обработано 3440 строк из 20000
# Обработано 3460 строк из 20000
# Обработано 3480 строк из 20000
# Обработано 3500 строк из 20000
# Обработано 3520 строк из 20000
# Обработано 3540 строк из 20000
# Обработано 3560 строк из 20000
# Обработано 3580 строк из 20000
# Обработано 3600 строк из 20000
# Обработано 3620 строк из 20000
# Обработано 3640 строк из 20000
# Обработано 3660 строк из 20000
# Обработано 3680 строк из 20000
# Обработано 3700 строк из 20000
# Обработано 3720 строк из 20000
# Обработано 3740 строк из 20000
# Обработано 3760 строк из 20000
# Обработано 3780 строк из 20000
# Обработано 3800 строк из 20000
# Обработано 3820 строк из 20000
# Обработано 3840 строк из 20000
# Обработано 3860 строк из 20000
# Обработано 3880 строк из 20000
# Обработано 3900 строк из 20000
# Обработано 3920 строк из 20000
# Обработано 3940 строк из 20000
# Обработано 3960 строк из 20000
# Обработано 3980 строк из 20000
# Обработано 4000 строк из 20000
# Обработано 4020 строк из 20000
# Обработано 4040 строк из 20000
# Обработано 4060 строк из 20000
# Обработано 4080 строк из 20000
# Обработано 4100 строк из 20000
# Обработано 4120 строк из 20000
# Обработано 4140 строк из 20000
# Обработано 4160 строк из 20000
# Обработано 4180 строк из 20000
# Обработано 4200 строк из 20000
# Обработано 4220 строк из 20000
# Обработано 4240 строк из 20000
# Обработано 4260 строк из 20000
# Обработано 4280 строк из 20000
# Обработано 4300 строк из 20000
# Обработано 4320 строк из 20000
# Обработано 4340 строк из 20000
# Обработано 4360 строк из 20000
# Обработано 4380 строк из 20000
# Обработано 4400 строк из 20000
# Обработано 4420 строк из 20000
# Обработано 4440 строк из 20000
# Обработано 4460 строк из 20000
# Обработано 4480 строк из 20000
# Обработано 4500 строк из 20000
# Обработано 4520 строк из 20000
# Обработано 4540 строк из 20000
# Обработано 4560 строк из 20000
# Обработано 4580 строк из 20000
# Обработано 4600 строк из 20000
# Обработано 4620 строк из 20000
# Обработано 4640 строк из 20000
# Обработано 4660 строк из 20000
# Обработано 4680 строк из 20000
# Обработано 4700 строк из 20000
# Обработано 4720 строк из 20000
# Обработано 4740 строк из 20000
# Обработано 4760 строк из 20000
# Обработано 4780 строк из 20000
# Обработано 4800 строк из 20000
# Обработано 4820 строк из 20000
# Обработано 4840 строк из 20000
# Обработано 4860 строк из 20000
# Обработано 4880 строк из 20000
# Обработано 4900 строк из 20000
# Обработано 4920 строк из 20000
# Обработано 4940 строк из 20000
# Обработано 4960 строк из 20000
# Обработано 4980 строк из 20000
# Обработано 5000 строк из 20000
# Обработано 5020 строк из 20000
# Обработано 5040 строк из 20000
# Обработано 5060 строк из 20000
# Обработано 5080 строк из 20000
# Обработано 5100 строк из 20000
# Обработано 5120 строк из 20000
# Обработано 5140 строк из 20000
# Обработано 5160 строк из 20000
# Обработано 5180 строк из 20000
# Обработано 5200 строк из 20000
# Обработано 5220 строк из 20000
# Обработано 5240 строк из 20000
# Обработано 5260 строк из 20000
# Обработано 5280 строк из 20000
# Обработано 5300 строк из 20000
# Обработано 5320 строк из 20000
# Обработано 5340 строк из 20000
# Обработано 5360 строк из 20000
# Обработано 5380 строк из 20000
# Обработано 5400 строк из 20000
# Обработано 5420 строк из 20000
# Обработано 5440 строк из 20000
# Обработано 5460 строк из 20000
# Обработано 5480 строк из 20000
# Обработано 5500 строк из 20000
# Обработано 5520 строк из 20000
# Обработано 5540 строк из 20000
# Обработано 5560 строк из 20000
# Обработано 5580 строк из 20000
# Обработано 5600 строк из 20000
# Обработано 5620 строк из 20000
# Обработано 5640 строк из 20000
# Обработано 5660 строк из 20000
# Обработано 5680 строк из 20000
# Обработано 5700 строк из 20000
# Обработано 5720 строк из 20000
# Обработано 5740 строк из 20000
# Обработано 5760 строк из 20000
# Обработано 5780 строк из 20000
# Обработано 5800 строк из 20000
# Обработано 5820 строк из 20000
# Обработано 5840 строк из 20000
# Обработано 5860 строк из 20000
# Обработано 5880 строк из 20000
# Обработано 5900 строк из 20000
# Обработано 5920 строк из 20000
# Обработано 5940 строк из 20000
# Обработано 5960 строк из 20000
# Обработано 5980 строк из 20000
# Обработано 6000 строк из 20000
# Обработано 6020 строк из 20000
# Обработано 6040 строк из 20000
# Обработано 6060 строк из 20000
# Обработано 6080 строк из 20000
# Обработано 6100 строк из 20000
# Обработано 6120 строк из 20000
# Обработано 6140 строк из 20000
# Обработано 6160 строк из 20000
# Обработано 6180 строк из 20000
# Обработано 6200 строк из 20000
# Обработано 6220 строк из 20000
# Обработано 6240 строк из 20000
# Обработано 6260 строк из 20000
# Обработано 6280 строк из 20000
# Обработано 6300 строк из 20000
# Обработано 6320 строк из 20000
# Обработано 6340 строк из 20000
# Обработано 6360 строк из 20000
# Обработано 6380 строк из 20000
# Обработано 6400 строк из 20000
# Обработано 6420 строк из 20000
# Обработано 6440 строк из 20000
# Обработано 6460 строк из 20000
# Обработано 6480 строк из 20000
# Обработано 6500 строк из 20000
# Обработано 6520 строк из 20000
# Обработано 6540 строк из 20000
# Обработано 6560 строк из 20000
# Обработано 6580 строк из 20000
# Обработано 6600 строк из 20000
# Обработано 6620 строк из 20000
# Обработано 6640 строк из 20000
# Обработано 6660 строк из 20000
# Обработано 6680 строк из 20000
# Обработано 6700 строк из 20000
# Обработано 6720 строк из 20000
# Обработано 6740 строк из 20000
# Обработано 6760 строк из 20000
# Обработано 6780 строк из 20000
# Обработано 6800 строк из 20000
# Обработано 6820 строк из 20000
# Обработано 6840 строк из 20000
# Обработано 6860 строк из 20000
# Обработано 6880 строк из 20000
# Обработано 6900 строк из 20000
# Обработано 6920 строк из 20000
# Обработано 6940 строк из 20000
# Обработано 6960 строк из 20000
# Обработано 6980 строк из 20000
# Обработано 7000 строк из 20000
# Обработано 7020 строк из 20000
# Обработано 7040 строк из 20000
# Обработано 7060 строк из 20000
# Обработано 7080 строк из 20000
# Обработано 7100 строк из 20000
# Обработано 7120 строк из 20000
# Обработано 7140 строк из 20000
# Обработано 7160 строк из 20000
# Обработано 7180 строк из 20000
# Обработано 7200 строк из 20000
# Обработано 7220 строк из 20000
# Обработано 7240 строк из 20000
# Обработано 7260 строк из 20000
# Обработано 7280 строк из 20000
# Обработано 7300 строк из 20000
# Обработано 7320 строк из 20000
# Обработано 7340 строк из 20000
# Обработано 7360 строк из 20000
# Обработано 7380 строк из 20000
# Обработано 7400 строк из 20000
# Обработано 7420 строк из 20000
# Обработано 7440 строк из 20000
# Обработано 7460 строк из 20000
# Обработано 7480 строк из 20000
# Обработано 7500 строк из 20000
# Обработано 7520 строк из 20000
# Обработано 7540 строк из 20000
# Обработано 7560 строк из 20000
# Обработано 7580 строк из 20000
# Обработано 7600 строк из 20000
# Обработано 7620 строк из 20000
# Обработано 7640 строк из 20000
# Обработано 7660 строк из 20000
# Обработано 7680 строк из 20000
# Обработано 7700 строк из 20000
# Обработано 7720 строк из 20000
# Обработано 7740 строк из 20000
# Обработано 7760 строк из 20000
# Обработано 7780 строк из 20000
# Обработано 7800 строк из 20000
# Обработано 7820 строк из 20000
# Обработано 7840 строк из 20000
# Обработано 7860 строк из 20000
# Обработано 7880 строк из 20000
# Обработано 7900 строк из 20000
# Обработано 7920 строк из 20000
# Обработано 7940 строк из 20000
# Обработано 7960 строк из 20000
# Обработано 7980 строк из 20000
# Обработано 8000 строк из 20000
# Обработано 8020 строк из 20000
# Обработано 8040 строк из 20000
# Обработано 8060 строк из 20000
# Обработано 8080 строк из 20000
# Обработано 8100 строк из 20000
# Обработано 8120 строк из 20000
# Обработано 8140 строк из 20000
# Обработано 8160 строк из 20000
# Обработано 8180 строк из 20000
# Обработано 8200 строк из 20000
# Обработано 8220 строк из 20000
# Обработано 8240 строк из 20000
# Обработано 8260 строк из 20000
# Обработано 8280 строк из 20000
# Обработано 8300 строк из 20000
# Обработано 8320 строк из 20000
# Обработано 8340 строк из 20000
# Обработано 8360 строк из 20000
# Обработано 8380 строк из 20000
# Обработано 8400 строк из 20000
# Обработано 8420 строк из 20000
# Обработано 8440 строк из 20000
# Обработано 8460 строк из 20000
# Обработано 8480 строк из 20000
# Обработано 8500 строк из 20000
# Обработано 8520 строк из 20000
# Обработано 8540 строк из 20000
# Обработано 8560 строк из 20000
# Обработано 8580 строк из 20000
# Обработано 8600 строк из 20000
# Обработано 8620 строк из 20000
# Обработано 8640 строк из 20000
# Обработано 8660 строк из 20000
# Обработано 8680 строк из 20000
# Обработано 8700 строк из 20000
# Обработано 8720 строк из 20000
# Обработано 8740 строк из 20000
# Обработано 8760 строк из 20000
# Обработано 8780 строк из 20000
# Обработано 8800 строк из 20000
# Обработано 8820 строк из 20000
# Обработано 8840 строк из 20000
# Обработано 8860 строк из 20000
# Обработано 8880 строк из 20000
# Обработано 8900 строк из 20000
# Обработано 8920 строк из 20000
# Обработано 8940 строк из 20000
# Обработано 8960 строк из 20000
# Обработано 8980 строк из 20000
# Обработано 9000 строк из 20000
# Обработано 9020 строк из 20000
# Обработано 9040 строк из 20000
# Обработано 9060 строк из 20000
# Обработано 9080 строк из 20000
# Обработано 9100 строк из 20000
# Обработано 9120 строк из 20000
# Обработано 9140 строк из 20000
# Обработано 9160 строк из 20000
# Обработано 9180 строк из 20000
# Обработано 9200 строк из 20000
# Обработано 9220 строк из 20000
# Обработано 9240 строк из 20000
# Обработано 9260 строк из 20000
# Обработано 9280 строк из 20000
# Обработано 9300 строк из 20000
# Обработано 9320 строк из 20000
# Обработано 9340 строк из 20000
# Обработано 9360 строк из 20000
# Обработано 9380 строк из 20000
# Обработано 9400 строк из 20000
# Обработано 9420 строк из 20000
# Обработано 9440 строк из 20000
# Обработано 9460 строк из 20000
# Обработано 9480 строк из 20000
# Обработано 9500 строк из 20000
# Обработано 9520 строк из 20000
# Обработано 9540 строк из 20000
# Обработано 9560 строк из 20000
# Обработано 9580 строк из 20000
# Обработано 9600 строк из 20000
# Обработано 9620 строк из 20000
# Обработано 9640 строк из 20000
# Обработано 9660 строк из 20000
# Обработано 9680 строк из 20000
# Обработано 9700 строк из 20000
# Обработано 9720 строк из 20000
# Обработано 9740 строк из 20000
# Обработано 9760 строк из 20000
# Обработано 9780 строк из 20000
# Обработано 9800 строк из 20000
# Обработано 9820 строк из 20000
# Обработано 9840 строк из 20000
# Обработано 9860 строк из 20000
# Обработано 9880 строк из 20000
# Обработано 9900 строк из 20000
# Обработано 9920 строк из 20000
# Обработано 9940 строк из 20000
# Обработано 9960 строк из 20000
# Обработано 9980 строк из 20000
# Обработано 10000 строк из 20000
# Обработано 10020 строк из 20000
# Обработано 10040 строк из 20000
# Обработано 10060 строк из 20000
# Обработано 10080 строк из 20000
# Обработано 10100 строк из 20000
# Обработано 10120 строк из 20000
# Обработано 10140 строк из 20000
# Обработано 10160 строк из 20000
# Обработано 10180 строк из 20000
# Обработано 10200 строк из 20000
# Обработано 10220 строк из 20000
# Обработано 10240 строк из 20000
# Обработано 10260 строк из 20000
# Обработано 10280 строк из 20000
# Обработано 10300 строк из 20000
# Обработано 10320 строк из 20000
# Обработано 10340 строк из 20000
# Обработано 10360 строк из 20000
# Обработано 10380 строк из 20000
# Обработано 10400 строк из 20000
# Обработано 10420 строк из 20000
# Обработано 10440 строк из 20000
# Обработано 10460 строк из 20000
# Обработано 10480 строк из 20000
# Обработано 10500 строк из 20000
# Обработано 10520 строк из 20000
# Обработано 10540 строк из 20000
# Обработано 10560 строк из 20000
# Обработано 10580 строк из 20000
# Обработано 10600 строк из 20000
# Обработано 10620 строк из 20000
# Обработано 10640 строк из 20000
# Обработано 10660 строк из 20000
# Обработано 10680 строк из 20000
# Обработано 10700 строк из 20000
# Обработано 10720 строк из 20000
# Обработано 10740 строк из 20000
# Обработано 10760 строк из 20000
# Обработано 10780 строк из 20000
# Обработано 10800 строк из 20000
# Обработано 10820 строк из 20000
# Обработано 10840 строк из 20000
# Обработано 10860 строк из 20000
# Обработано 10880 строк из 20000
# Обработано 10900 строк из 20000
# Обработано 10920 строк из 20000
# Обработано 10940 строк из 20000
# Обработано 10960 строк из 20000
# Обработано 10980 строк из 20000
# Обработано 11000 строк из 20000
# Обработано 11020 строк из 20000
# Обработано 11040 строк из 20000
# Обработано 11060 строк из 20000
# Обработано 11080 строк из 20000
# Обработано 11100 строк из 20000
# Обработано 11120 строк из 20000
# Обработано 11140 строк из 20000
# Обработано 11160 строк из 20000
# Обработано 11180 строк из 20000
# Обработано 11200 строк из 20000
# Обработано 11220 строк из 20000
# Обработано 11240 строк из 20000
# Обработано 11260 строк из 20000
# Обработано 11280 строк из 20000
# Обработано 11300 строк из 20000
# Обработано 11320 строк из 20000
# Обработано 11340 строк из 20000
# Обработано 11360 строк из 20000
# Обработано 11380 строк из 20000
# Обработано 11400 строк из 20000
# Обработано 11420 строк из 20000
# Обработано 11440 строк из 20000
# Обработано 11460 строк из 20000
# Обработано 11480 строк из 20000
# Обработано 11500 строк из 20000
# Обработано 11520 строк из 20000
# Обработано 11540 строк из 20000
# Обработано 11560 строк из 20000
# Обработано 11580 строк из 20000
# Обработано 11600 строк из 20000
# Обработано 11620 строк из 20000
# Обработано 11640 строк из 20000
# Обработано 11660 строк из 20000
# Обработано 11680 строк из 20000
# Обработано 11700 строк из 20000
# Обработано 11720 строк из 20000
# Обработано 11740 строк из 20000
# Обработано 11760 строк из 20000
# Обработано 11780 строк из 20000
# Обработано 11800 строк из 20000
# Обработано 11820 строк из 20000
# Обработано 11840 строк из 20000
# Обработано 11860 строк из 20000
# Обработано 11880 строк из 20000
# Обработано 11900 строк из 20000
# Обработано 11920 строк из 20000
# Обработано 11940 строк из 20000
# Обработано 11960 строк из 20000
# Обработано 11980 строк из 20000
# Обработано 12000 строк из 20000
# Обработано 12020 строк из 20000
# Обработано 12040 строк из 20000
# Обработано 12060 строк из 20000
# Обработано 12080 строк из 20000
# Обработано 12100 строк из 20000
# Обработано 12120 строк из 20000
# Обработано 12140 строк из 20000
# Обработано 12160 строк из 20000
# Обработано 12180 строк из 20000
# Обработано 12200 строк из 20000
# Обработано 12220 строк из 20000
# Обработано 12240 строк из 20000
# Обработано 12260 строк из 20000
# Обработано 12280 строк из 20000
# Обработано 12300 строк из 20000
# Обработано 12320 строк из 20000
# Обработано 12340 строк из 20000
# Обработано 12360 строк из 20000
# Обработано 12380 строк из 20000
# Обработано 12400 строк из 20000
# Обработано 12420 строк из 20000
# Обработано 12440 строк из 20000
# Обработано 12460 строк из 20000
# Обработано 12480 строк из 20000
# Обработано 12500 строк из 20000
# Обработано 12520 строк из 20000
# Обработано 12540 строк из 20000
# Обработано 12560 строк из 20000
# Обработано 12580 строк из 20000
# Обработано 12600 строк из 20000
# Обработано 12620 строк из 20000
# Обработано 12640 строк из 20000
# Обработано 12660 строк из 20000
# Обработано 12680 строк из 20000
# Обработано 12700 строк из 20000
# Обработано 12720 строк из 20000
# Обработано 12740 строк из 20000
# Обработано 12760 строк из 20000
# Обработано 12780 строк из 20000
# Обработано 12800 строк из 20000
# Обработано 12820 строк из 20000
# Обработано 12840 строк из 20000
# Обработано 12860 строк из 20000
# Обработано 12880 строк из 20000
# Обработано 12900 строк из 20000
# Обработано 12920 строк из 20000
# Обработано 12940 строк из 20000
# Обработано 12960 строк из 20000
# Обработано 12980 строк из 20000
# Обработано 13000 строк из 20000
# Обработано 13020 строк из 20000
# Обработано 13040 строк из 20000
# Обработано 13060 строк из 20000
# Обработано 13080 строк из 20000
# Обработано 13100 строк из 20000
# Обработано 13120 строк из 20000
# Обработано 13140 строк из 20000
# Обработано 13160 строк из 20000
# Обработано 13180 строк из 20000
# Обработано 13200 строк из 20000
# Обработано 13220 строк из 20000
# Обработано 13240 строк из 20000
# Обработано 13260 строк из 20000
# Обработано 13280 строк из 20000
# Обработано 13300 строк из 20000
# Обработано 13320 строк из 20000
# Обработано 13340 строк из 20000
# Обработано 13360 строк из 20000
# Обработано 13380 строк из 20000
# Обработано 13400 строк из 20000
# Обработано 13420 строк из 20000
# Обработано 13440 строк из 20000
# Обработано 13460 строк из 20000
# Обработано 13480 строк из 20000
# Обработано 13500 строк из 20000
# Обработано 13520 строк из 20000
# Обработано 13540 строк из 20000
# Обработано 13560 строк из 20000
# Обработано 13580 строк из 20000
# Обработано 13600 строк из 20000
# Обработано 13620 строк из 20000
# Обработано 13640 строк из 20000
# Обработано 13660 строк из 20000
# Обработано 13680 строк из 20000
# Обработано 13700 строк из 20000
# Обработано 13720 строк из 20000
# Обработано 13740 строк из 20000
# Обработано 13760 строк из 20000
# Обработано 13780 строк из 20000
# Обработано 13800 строк из 20000
# Обработано 13820 строк из 20000
# Обработано 13840 строк из 20000
# Обработано 13860 строк из 20000
# Обработано 13880 строк из 20000
# Обработано 13900 строк из 20000
# Обработано 13920 строк из 20000
# Обработано 13940 строк из 20000
# Обработано 13960 строк из 20000
# Обработано 13980 строк из 20000
# Обработано 14000 строк из 20000
# Обработано 14020 строк из 20000
# Обработано 14040 строк из 20000
# Обработано 14060 строк из 20000
# Обработано 14080 строк из 20000
# Обработано 14100 строк из 20000
# Обработано 14120 строк из 20000
# Обработано 14140 строк из 20000
# Обработано 14160 строк из 20000
# Обработано 14180 строк из 20000
# Обработано 14200 строк из 20000
# Обработано 14220 строк из 20000
# Обработано 14240 строк из 20000
# Обработано 14260 строк из 20000
# Обработано 14280 строк из 20000
# Обработано 14300 строк из 20000
# Обработано 14320 строк из 20000
# Обработано 14340 строк из 20000
# Обработано 14360 строк из 20000
# Обработано 14380 строк из 20000
# Обработано 14400 строк из 20000
# Обработано 14420 строк из 20000
# Обработано 14440 строк из 20000
# Обработано 14460 строк из 20000
# Обработано 14480 строк из 20000
# Обработано 14500 строк из 20000
# Обработано 14520 строк из 20000
# Обработано 14540 строк из 20000
# Обработано 14560 строк из 20000
# Обработано 14580 строк из 20000
# Обработано 14600 строк из 20000
# Обработано 14620 строк из 20000
# Обработано 14640 строк из 20000
# Обработано 14660 строк из 20000
# Обработано 14680 строк из 20000
# Обработано 14700 строк из 20000
# Обработано 14720 строк из 20000
# Обработано 14740 строк из 20000
# Обработано 14760 строк из 20000
# Обработано 14780 строк из 20000
# Обработано 14800 строк из 20000
# Обработано 14820 строк из 20000
# Обработано 14840 строк из 20000
# Обработано 14860 строк из 20000
# Обработано 14880 строк из 20000
# Обработано 14900 строк из 20000
# Обработано 14920 строк из 20000
# Обработано 14940 строк из 20000
# Обработано 14960 строк из 20000
# Обработано 14980 строк из 20000
# Обработано 15000 строк из 20000
# Обработано 15020 строк из 20000
# Обработано 15040 строк из 20000
# Обработано 15060 строк из 20000
# Обработано 15080 строк из 20000
# Обработано 15100 строк из 20000
# Обработано 15120 строк из 20000
# Обработано 15140 строк из 20000
# Обработано 15160 строк из 20000
# Обработано 15180 строк из 20000
# Обработано 15200 строк из 20000
# Обработано 15220 строк из 20000
# Обработано 15240 строк из 20000
# Обработано 15260 строк из 20000
# Обработано 15280 строк из 20000
# Обработано 15300 строк из 20000
# Обработано 15320 строк из 20000
# Обработано 15340 строк из 20000
# Обработано 15360 строк из 20000
# Обработано 15380 строк из 20000
# Обработано 15400 строк из 20000
# Обработано 15420 строк из 20000
# Обработано 15440 строк из 20000
# Обработано 15460 строк из 20000
# Обработано 15480 строк из 20000
# Обработано 15500 строк из 20000
# Обработано 15520 строк из 20000
# Обработано 15540 строк из 20000
# Обработано 15560 строк из 20000
# Обработано 15580 строк из 20000
# Обработано 15600 строк из 20000
# Обработано 15620 строк из 20000
# Обработано 15640 строк из 20000
# Обработано 15660 строк из 20000
# Обработано 15680 строк из 20000
# Обработано 15700 строк из 20000
# Обработано 15720 строк из 20000
# Обработано 15740 строк из 20000
# Обработано 15760 строк из 20000
# Обработано 15780 строк из 20000
# Обработано 15800 строк из 20000
# Обработано 15820 строк из 20000
# Обработано 15840 строк из 20000
# Обработано 15860 строк из 20000
# Обработано 15880 строк из 20000
# Обработано 15900 строк из 20000
# Обработано 15920 строк из 20000
# Обработано 15940 строк из 20000
# Обработано 15960 строк из 20000
# Обработано 15980 строк из 20000
# Обработано 16000 строк из 20000
# Обработано 16020 строк из 20000
# Обработано 16040 строк из 20000
# Обработано 16060 строк из 20000
# Обработано 16080 строк из 20000
# Обработано 16100 строк из 20000
# Обработано 16120 строк из 20000
# Обработано 16140 строк из 20000
# Обработано 16160 строк из 20000
# Обработано 16180 строк из 20000
# Обработано 16200 строк из 20000
# Обработано 16220 строк из 20000
# Обработано 16240 строк из 20000
# Обработано 16260 строк из 20000
# Обработано 16280 строк из 20000
# Обработано 16300 строк из 20000
# Обработано 16320 строк из 20000
# Обработано 16340 строк из 20000
# Обработано 16360 строк из 20000
# Обработано 16380 строк из 20000
# Обработано 16400 строк из 20000
# Обработано 16420 строк из 20000
# Обработано 16440 строк из 20000
# Обработано 16460 строк из 20000
# Обработано 16480 строк из 20000
# Обработано 16500 строк из 20000
# Обработано 16520 строк из 20000
# Обработано 16540 строк из 20000
# Обработано 16560 строк из 20000
# Обработано 16580 строк из 20000
# Обработано 16600 строк из 20000
# Обработано 16620 строк из 20000
# Обработано 16640 строк из 20000
# Обработано 16660 строк из 20000
# Обработано 16680 строк из 20000
# Обработано 16700 строк из 20000
# Обработано 16720 строк из 20000
# Обработано 16740 строк из 20000
# Обработано 16760 строк из 20000
# Обработано 16780 строк из 20000
# Обработано 16800 строк из 20000
# Обработано 16820 строк из 20000
# Обработано 16840 строк из 20000
# Обработано 16860 строк из 20000
# Обработано 16880 строк из 20000
# Обработано 16900 строк из 20000
# Обработано 16920 строк из 20000
# Обработано 16940 строк из 20000
# Обработано 16960 строк из 20000
# Обработано 16980 строк из 20000
# Обработано 17000 строк из 20000
# Обработано 17020 строк из 20000
# Обработано 17040 строк из 20000
# Обработано 17060 строк из 20000
# Обработано 17080 строк из 20000
# Обработано 17100 строк из 20000
# Обработано 17120 строк из 20000
# Обработано 17140 строк из 20000
# Обработано 17160 строк из 20000
# Обработано 17180 строк из 20000
# Обработано 17200 строк из 20000
# Обработано 17220 строк из 20000
# Обработано 17240 строк из 20000
# Обработано 17260 строк из 20000
# Обработано 17280 строк из 20000
# Обработано 17300 строк из 20000
# Обработано 17320 строк из 20000
# Обработано 17340 строк из 20000
# Обработано 17360 строк из 20000
# Обработано 17380 строк из 20000
# Обработано 17400 строк из 20000
# Обработано 17420 строк из 20000
# Обработано 17440 строк из 20000
# Обработано 17460 строк из 20000
# Обработано 17480 строк из 20000
# Обработано 17500 строк из 20000
# Обработано 17520 строк из 20000
# Обработано 17540 строк из 20000
# Обработано 17560 строк из 20000
# Обработано 17580 строк из 20000
# Обработано 17600 строк из 20000
# Обработано 17620 строк из 20000
# Обработано 17640 строк из 20000
# Обработано 17660 строк из 20000
# Обработано 17680 строк из 20000
# Обработано 17700 строк из 20000
# Обработано 17720 строк из 20000
# Обработано 17740 строк из 20000
# Обработано 17760 строк из 20000
# Обработано 17780 строк из 20000
# Обработано 17800 строк из 20000
# Обработано 17820 строк из 20000
# Обработано 17840 строк из 20000
# Обработано 17860 строк из 20000
# Обработано 17880 строк из 20000
# Обработано 17900 строк из 20000
# Обработано 17920 строк из 20000
# Обработано 17940 строк из 20000
# Обработано 17960 строк из 20000
# Обработано 17980 строк из 20000
# Обработано 18000 строк из 20000
# Обработано 18020 строк из 20000
# Обработано 18040 строк из 20000
# Обработано 18060 строк из 20000
# Обработано 18080 строк из 20000
# Обработано 18100 строк из 20000
# Обработано 18120 строк из 20000
# Обработано 18140 строк из 20000
# Обработано 18160 строк из 20000
# Обработано 18180 строк из 20000
# Обработано 18200 строк из 20000
# Обработано 18220 строк из 20000
# Обработано 18240 строк из 20000
# Обработано 18260 строк из 20000
# Обработано 18280 строк из 20000
# Обработано 18300 строк из 20000
# Обработано 18320 строк из 20000
# Обработано 18340 строк из 20000
# Обработано 18360 строк из 20000
# Обработано 18380 строк из 20000
# Обработано 18400 строк из 20000
# Обработано 18420 строк из 20000
# Обработано 18440 строк из 20000
# Обработано 18460 строк из 20000
# Обработано 18480 строк из 20000
# Обработано 18500 строк из 20000
# Обработано 18520 строк из 20000
# Обработано 18540 строк из 20000
# Обработано 18560 строк из 20000
# Обработано 18580 строк из 20000
# Обработано 18600 строк из 20000
# Обработано 18620 строк из 20000
# Обработано 18640 строк из 20000
# Обработано 18660 строк из 20000
# Обработано 18680 строк из 20000
# Обработано 18700 строк из 20000
# Обработано 18720 строк из 20000
# Обработано 18740 строк из 20000
# Обработано 18760 строк из 20000
# Обработано 18780 строк из 20000
# Обработано 18800 строк из 20000
# Обработано 18820 строк из 20000
# Обработано 18840 строк из 20000
# Обработано 18860 строк из 20000
# Обработано 18880 строк из 20000
# Обработано 18900 строк из 20000
# Обработано 18920 строк из 20000
# Обработано 18940 строк из 20000
# Обработано 18960 строк из 20000
# Обработано 18980 строк из 20000
# Обработано 19000 строк из 20000
# Обработано 19020 строк из 20000
# Обработано 19040 строк из 20000
# Обработано 19060 строк из 20000
# Обработано 19080 строк из 20000
# Обработано 19100 строк из 20000
# Обработано 19120 строк из 20000
# Обработано 19140 строк из 20000
# Обработано 19160 строк из 20000
# Обработано 19180 строк из 20000
# Обработано 19200 строк из 20000
# Обработано 19220 строк из 20000
# Обработано 19240 строк из 20000
# Обработано 19260 строк из 20000
# Обработано 19280 строк из 20000
# Обработано 19300 строк из 20000
# Обработано 19320 строк из 20000
# Обработано 19340 строк из 20000
# Обработано 19360 строк из 20000
# Обработано 19380 строк из 20000
# Обработано 19400 строк из 20000
# Обработано 19420 строк из 20000
# Обработано 19440 строк из 20000
# Обработано 19460 строк из 20000
# Обработано 19480 строк из 20000
# Обработано 19500 строк из 20000
# Обработано 19520 строк из 20000
# Обработано 19540 строк из 20000
# Обработано 19560 строк из 20000
# Обработано 19580 строк из 20000
# Обработано 19600 строк из 20000
# Обработано 19620 строк из 20000
# Обработано 19640 строк из 20000
# Обработано 19660 строк из 20000
# Обработано 19680 строк из 20000
# Обработано 19700 строк из 20000
# Обработано 19720 строк из 20000
# Обработано 19740 строк из 20000
# Обработано 19760 строк из 20000
# Обработано 19780 строк из 20000
# Обработано 19800 строк из 20000
# Обработано 19820 строк из 20000
# Обработано 19840 строк из 20000
# Обработано 19860 строк из 20000
# Обработано 19880 строк из 20000
# Обработано 19900 строк из 20000
# Обработано 19920 строк из 20000
# Обработано 19940 строк из 20000
# Обработано 19960 строк из 20000
# Обработано 19980 строк из 20000
# Обработано 20000 строк из 20000
# Обработка завершена.

# %%
df['gruut_phonemes'] = df['gruut_phonemes'].apply(lambda x: re.sub(r'[ˈˌ]', '', x))
df['gruut_phonemes'] = df['gruut_phonemes'].apply(lambda x: x.split())
df.head()
# Out:
#                                           audio_path  \
# 0  /home/morph/Desktop/FINAL/LS/train-other-500/L...
# 1  /home/morph/Desktop/FINAL/LS/train-other-500/L...
# 2  /home/morph/Desktop/FINAL/LS/train-other-500/L...
# 3  /home/morph/Desktop/FINAL/LS/train-other-500/L...
# 4  /home/morph/Desktop/FINAL/LS/train-other-500/L...
#
#                                             sentence  \
# 0  CHAPTER TWENTY FIVE A VISIT FROM LOUISE THAT D...
# 1  TO STIFLE HER WITH HOUSEHOLD AMMONIA AND LIDDY...
# 2  SHE CLUTCHED AT MY SLEEVE WHEN I WENT CLOSE TO...
# 3  COMING JUST AFTER THE FIRE THE HOUSEHOLD WAS D...
# 4  BUT SHE WAS SO EXCITED I WAS AFRAID SHE WOULD ...
#
#                                       gruut_phonemes
# 0  [t͡ʃæptɚ, twɛnti, faɪv, ə, vɪzɪt, fɹʌm, luiz, ...
# 1  [tə, staɪfəl, hɚ, wɪθ, haʊshoʊld, əmoʊnjə, ænd...
# 2  [ʃi, klʌt͡ʃt, æt, maɪ, sliv, wɛn, aɪ, wɛnt, kl...
# 3  [kʌmɪŋ, d͡ʒʌst, æftɚ, ðə, faɪɚ, ðə, haʊshoʊld,...
# 4  [bʌt, ʃi, wəz, soʊ, ɪksaɪtɪd, aɪ, wəz, əfɹeɪd,...

# %%
def get_duration_in_minutes(audio_path):
    audio_info = mediainfo(audio_path)
    duration_seconds = float(audio_info['duration'])
    return duration_seconds / 60 

df['duration'] = df['audio_path'].apply(get_duration_in_minutes)

# %%
final_df = df[['audio_path', 'sentence', 'gruut_phonemes', 'duration']].copy()
final_df.columns = ['audio_path', 'sentence', 'gruut_phonemes', 'duration']

final_df.head()
# Out:
#                                           audio_path  \
# 0  /home/morph/Desktop/FINAL/LS/train-other-500/L...
# 1  /home/morph/Desktop/FINAL/LS/train-other-500/L...
# 2  /home/morph/Desktop/FINAL/LS/train-other-500/L...
# 3  /home/morph/Desktop/FINAL/LS/train-other-500/L...
# 4  /home/morph/Desktop/FINAL/LS/train-other-500/L...
#
#                                             sentence  \
# 0  CHAPTER TWENTY FIVE A VISIT FROM LOUISE THAT D...
# 1  TO STIFLE HER WITH HOUSEHOLD AMMONIA AND LIDDY...
# 2  SHE CLUTCHED AT MY SLEEVE WHEN I WENT CLOSE TO...
# 3  COMING JUST AFTER THE FIRE THE HOUSEHOLD WAS D...
# 4  BUT SHE WAS SO EXCITED I WAS AFRAID SHE WOULD ...
#
#                                       gruut_phonemes  duration
# 0  [t͡ʃæptɚ, twɛnti, faɪv, ə, vɪzɪt, fɹʌm, luiz, ...  0.236833
# 1  [tə, staɪfəl, hɚ, wɪθ, haʊshoʊld, əmoʊnjə, ænd...  0.249167
# 2  [ʃi, klʌt͡ʃt, æt, maɪ, sliv, wɛn, aɪ, wɛnt, kl...  0.071583
# 3  [kʌmɪŋ, d͡ʒʌst, æftɚ, ðə, faɪɚ, ðə, haʊshoʊld,...  0.179167
# 4  [bʌt, ʃi, wəz, soʊ, ɪksaɪtɪd, aɪ, wəz, əfɹeɪd,...  0.245750

# %%
total_duration = df['duration'].sum()

print(f'Общая длительность всего датасета: {total_duration:.2f} минут')
# Out:
# Общая длительность всего датасета: 4035.93 минут

# %%
total_duration / 60
# Out:
# np.float64(67.26553506444445)

# %%
final_df.to_csv('/home/morph/Desktop/FINAL/LSoutput/ls_dataset.csv', index=False)
